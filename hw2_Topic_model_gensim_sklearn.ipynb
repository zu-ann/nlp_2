# %% [markdown]
# ## Домашнее задание

# %% [markdown]
# Основаная задача - **построить хорошую тематическую модель с интерпретируемыми топиками с помощью LDA в gensim и NMF в sklearn**.
#
#
# 1) сделайте нормализацию (если pymorphy2 работает долго используйте mystem или попробуйте установить быструю версию - `pip install pymorphy2[fast]`, можно использовать какой-то другой токенизатор);
#
# 2) добавьте нграммы (в тетрадке есть закомменченая ячейка с Phrases,  можно также попробовать другие способы построить нграммы);
#
# 3) сделайте хороший словарь (отфильтруйте слишком частотные и редкие слова, попробуйте удалить стоп-слова);
#
# 4) постройте несколько LDA моделей (переберите количество тем, можете поменять eta, alpha, passes), если получаются плохие темы, поработайте дополнительно над предобработкой и словарем;
#
# 5) для самой хорошей модели в отдельной ячейке напечатайте 3 хороших (на ваш вкус) темы;
#
# 6) между словарем и обучением модели добавьте tfidf (`gensim.models.TfidfModel(corpus, id2word=dictionary); corpus = tfidf[corpus]`);
#
# 7) повторите пункт 4 на преобразованном корпусе;
#
# 8) в отдельной ячейке опишите как изменилась модель (приведите несколько тем, которые стали лучше или хуже, или которых раньше вообще не было; можно привести значения перплексии и когерентности для обеих моделей)
#
# 9) проделайте такие же действия для NMF (образец в конце тетрадки), для построения словаря воспользуйтесь возможностями Count или Tfidf Vectorizer (попробуйте другие значение max_features, min_df, max_df, сделайте нграмы через ngram_range, если хватает памяти), попробуйте такие же количества тем
#
# 10) в отдельной ячейки напечатайте таблицу с темами лучшей NMF модели, сравните их с теми, что получились в LDA.
#
# Сохраните тетрадку с экспериментами и положите её на гитхаб, ссылку на неё укажите в форме.
#
# **Оцениваться будут главным образом пункты 5, 8 и 10. (2, 3, 2 баллов соответственно). Чтобы заработать остальные 3 балла, нужно хотя бы немного изменить мой код на промежуточных этапах (добавить что-то, указать другие параметры и т.д). **

# %%
import gensim
import json
import re
import pickle
import pyLDAvis.gensim
import string
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from itertools import chain
from pymystem3 import Mystem
from collections import Counter

import warnings
warnings.filterwarnings("ignore")

mystem = Mystem()

# %% [markdown]
# ## Данные

# %%
stops = set(stopwords.words('russian')) | {'gt',}

def remove_tags(text):
    return re.sub(r'<[^>]+>', '', text)

def normalize(words):
    norm_words = [mystem.lemmatize(word)[0] for word in words if len(word) > 2 and word not in stops]
    return norm_words

def tokenize(text):
    words = [word.strip(string.punctuation) for word in text.split()]
    words = [word for word in words if word]
    
    return words

# %%
# %%time
texts = open('habr_texts.txt').read().splitlines()
texts = [normalize(tokenize(remove_tags(text.lower()))) for text in texts]
# Out:
# CPU times: user 3min 35s, sys: 58.1 s, total: 4min 34s
# Wall time: 8min 44s

# %%
with open('texts.json', 'w', encoding='utf-8') as fw:
    json.dump(texts, fw)

# %%
# для нграммов
ph = gensim.models.Phrases(texts, scoring='npmi', threshold=0.4) # threshold можно подбирать
p = gensim.models.phrases.Phraser(ph)
ngrammed_texts_4 = p[texts]

# %%
ngrammed_2 = set(chain.from_iterable(ngrammed_texts_2))

# %%
ngrammed_4 = set(chain.from_iterable(ngrammed_texts_4))

# %%
ngrammed_7 = set(chain.from_iterable(ngrammed_texts_7))

# %% [markdown]
# Сравним тексты, полученными со значением ```threshold```, равным 0.2, 0.4 и 0.7:

# %%
# пример первых 20 нграмм, которые есть в ngrammed_4 и нет в ngrammed_2
list(ngrammed_4.difference(ngrammed_2))[:20]
# Out:
# ['целый_матрешка',
#  'packed_double',
#  'недосмотр_вроде',
#  'возвращаться_ec2',
#  'ctx_wndclassw',
#  'dgst_sha256',
#  'среда_gomaxprocs',
#  'автономность_транка',
#  'broadridge_планировать',
#  'никод',
#  'bsim19_кнопка',
#  'a5d6a7_mdl',
#  'мвт_ассортимент',
#  'деление_нацело',
#  'радиокнопка_взаимодействовать',
#  'замороженый_деньги',
#  'генерить',
#  'gettransparent_write',
#  'дурной_чувствовать',
#  'познание_трехмерный']

# %% [markdown]
# В текстах с ```threshold = 0.4``` есть хорошие коллокации, например, *'вестминстерский_дворец'*, *'full\_installation'*, *'африканский\_кампания'*, *'похлопать\_плечо'*, которых нет в текстах с ```threshold = 0.2```.

# %%
# пример первых 20 нграмм, которые есть в ngrammed_7 и нет в ngrammed_4
list(ngrammed_7.difference(ngrammed_4))[:20]
# Out:
# ['securityz',
#  '1200t',
#  'cameradevice',
#  'ymin',
#  'doty',
#  'ipb',
#  'угнетаться',
#  'metropolitana',
#  'objectsatendinterval',
#  'ещёsudo_binwalk',
#  'слеплять',
#  'myspace',
#  'l40x2',
#  'нескончаемый',
#  'безвыходный',
#  'пирс',
#  'новостиupd',
#  'токарная',
#  'выкрикивать',
#  'противность']

# %% [markdown]
# Сравнивая тексты с ```threshold = 0.4``` и ```threshold = 0.7```, уже сложнее найти хорошие коллокации при ```threshold = 0.7```, которых нет при ```threshold = 0.4```, но некоторые находятся, например: *'зашевилиться_волос'* и *'остросюжетный_детектив'*.

# %% [markdown]
# ### Тематическое моделирование в gensim

# %%
def get_lda_model(texts, num_topics=100, passes=5, eta='auto', id2word=None, not_return_id2word=False, 
                     return_corpus=False):
    if not id2word:
        id2word = gensim.corpora.Dictionary(texts)
        id2word.filter_extremes(no_above=0.3)
        id2word.compactify()
    
        corpus = [id2word.doc2bow(text) for text in texts]
    else:
        corpus = texts
    
    lda = gensim.models.LdaMulticore(corpus, num_topics, id2word=id2word, passes=passes, eta=eta,
                                     iterations=10)
    
    print('Perplexity: ', lda.log_perplexity(corpus[:2000], total_docs=100))
    
    if return_corpus:
        return lda, id2word, corpus
    elif not_return_id2word:
        return lda
    else:
        return lda, id2word

# %%
def get_coherence(lda, dictionary, texts, n_col):
        
    topics = []
    word_dict = {}
    for topic_id, topic in lda.show_topics(num_topics=100, formatted=False):
        topic = [word for word, _ in topic]
        topics.append(topic)
        word_dict['Topic # ' + '{:02d}'.format(topic_id)] = topic
    
    coherence_model_lda = gensim.models.CoherenceModel(topics=topics, 
                                                       texts=texts, 
                                                       dictionary=dictionary, coherence='c_v')
    coherence = coherence_model_lda.get_coherence()
    print('Coherence: ', coherence)
    
    return coherence, pd.DataFrame(word_dict).iloc[:, 0:n_col]

# %% [markdown]
# Сравним результаты с разным ```threshold``` у нграмм:

# %%
lda_model_4, dictionary_4 = get_lda_model(ngrammed_texts_4)
c, topics = get_coherence(lda_model_4, dictionary_4, ngrammed_texts_4, 20)
topics
# Out:
# Coherence:  0.46843378662142304
#   Topic # 00 Topic # 01             Topic # 02    Topic # 03   Topic # 04  \
# 0   значение     сервер                   java  оборудование   устройство
# 1     ошибка       сеть                   язык    устройство         сеть
# 2     список   интернет                   ядро        модуль       доступ
# 3       файл     клиент                 память    контроллер        номер
# 4       поле     сервис                ребенок     программа       сервер
# 5     запрос     доступ              программа          дата     значение
# 6    элемент     google                телефон     компьютер  верификация
# 7        php     трафик                 openmp    управление       бизнес
# 8      print      пакет  язык_программирование       питание   спускаться
# 9         lt      связь             компилятор         лазер            4
#
#   Topic # 05   Topic # 06  Topic # 07     Topic # 08      Topic # 09  \
# 0      метод       return          up    import_java          сигнал
# 1     список       объект        2016         system       усилитель
# 2  поддержка  изображение    какой-то      void_main         частота
# 3      пакет        epoch       книга            new          бумага
# 4        qml       запрос  заниматься    public_void       искажение
# 5     модуль         боль          12  public_static        астероид
# 6         qt        класс          11        покупка            звук
# 7         if         type         час             if  обратный_связь
# 8  запускать            “   проходить        абонент        мощность
# 9         lt           if        путь             in       гармоника
#
#       Topic # 10   Topic # 11   Topic # 12   Topic # 13    Topic # 14  \
# 0       значение       монета      продукт       доклад       сборщик
# 1         пиксел     источник    сотрудник         тема        память
# 2         модель         view         цель  выступление     программа
# 3  временный_ряд       сигнал         сайт        игрок      алгоритм
# 4          точка         сайт       клиент       письмо           ssd
# 5            ита  изображение         идея         враг        размер
# 6         объект   устройство       что-то  конференция         метод
# 7        базовый          кит       бизнес         игра         пауза
# 8             20   технология  программист     рассылка  сборка_мусор
# 9        область        метод         опыт    подписчик            lt
#
#   Topic # 15 Topic # 16 Topic # 17  Topic # 18 Topic # 19
# 0         lt     объект     сервис        игра       игра
# 1        int    элемент     сервер   приставка   какой-то
# 2    for_int      домен  программа    nintendo     клиент
# 3   значение       файл       файл  устройство     pebble
# 4         if      вызов       сайт       робот      точка
# 5  long_long  программа     клиент      доллар         pc
# 6     return       сайт  сообщение        сеть        еще
# 7    элемент   страница     доступ  технология      набор
# 8        foo     ошибка       сеть    deepmind     ошибка
# 9     объект     opencv   интернет       агент        мир

# %%
lda_model_7, dictionary_7 = get_lda_model(ngrammed_texts_7)
c, topics = get_coherence(lda_model_7, dictionary_7, ngrammed_texts_7, 20)
topics
# Out:
# Coherence:  0.5000414555311885
#   Topic # 00 Topic # 01 Topic # 02  Topic # 03 Topic # 04 Topic # 05  \
# 0   значение       salt  компонент      сигнал    fortran         lt
# 1      товар     миньон     сервер      датчик    позиция       gulp
# 2     пиксел     мастер      react   квантовый   makerbot     import
# 3       font       ключ       this    значение     память       файл
# 4        100       rhel     return  транзистор      light     vendor
# 5         20       файл    элемент         ток        еще        0.0
# 6         mb    red_hat         lt       канал        int     сервер
# 7     размер     master     список     частота        the       ключ
# 8     скидка     сервер    vertica        поле   простыня        for
# 9          1  запускать         if       точка       игра  запускать
#
#    Topic # 06        Topic # 07 Topic # 08       Topic # 09 Topic # 10  \
# 0      машина              файл         ms           python       файл
# 1        диск           агрегат        sec            apple     docker
# 2  инструмент        устройство          5         операция     сервер
# 3      станок          значение        sum       устройство       http
# 4      протез                sr          4            рынок        etc
# 5      сервер             метод      адрес        программа  контейнер
# 6       мотор              сеть        2.1      собственный      nginx
# 7   измерение  кардиостимулятор        2.2              она  настройка
# 8      размер            jmeter    подсеть             мозг  запускать
# 9    текстура             метка       сеть  антимонопольный      https
#
#   Topic # 11  Topic # 12 Topic # 13  Topic # 14  Topic # 15  Topic # 16  \
# 0       глаз        файл  программа       value        сайт      модель
# 1   операция      ошибка     клиент          lt  устройство       рынок
# 2      swift   программа       сайт        ключ  технология  устройство
# 3   роговица       папка       язык        файл      бизнес   ассемблер
# 4      scrum    значение       сеть       hello    интернет      стекло
# 5      лазер  библиотека    торрент        сайт        сеть  pocketbook
# 6          “       класс  интерфейс         pin        курс    скорость
# 7    пациент        ядро   интернет  устройство      клиент       связь
# 8      линза         int   какой-то  сертификат   обработка  технология
# 9     хирург        тест     машина      сервер      google        сеть
#
#   Topic # 17    Topic # 18 Topic # 19
# 0       this    устройство    elapsed
# 1     public        камера      sleep
# 2     return      смартфон         lt
# 3    private        модель       test
# 4        new       телефон        std
# 5   function          сайт       time
# 6       void          цена   starting
# 7     объект         экран   значение
# 8     string      интернет      timer
# 9         if  безопасность      вывод

# %% [markdown]
# C ```threshold = 0.7``` значение ```coherence``` получилось выше всего. Попробуем дальше использовать именно этот ```threshold```.

# %% [markdown]
# Изменим предобработку: исключим из текстов цифры и двубуквенные слова.

# %%
stops = set(stopwords.words('russian'))
punct = string.punctuation + '»«–…”“' + string.digits

def remove_tags(text):
    return re.sub(r'<[^>]+>', '', text)

def normalize(words):
    norm_words = [mystem.lemmatize(word)[0] for word in words if len(word) > 2]
    norm_words = [word for word in norm_words if word not in stops]
    return norm_words

def tokenize(text):
    words = [word.strip(punct) for word in text.split()]
    words = [word for word in words if word]
    
    return words

# %%
texts_first = open('habr_texts.txt').read().splitlines()
texts = [normalize(tokenize(remove_tags(text.lower()))) for text in texts_first]

# %%
ph = gensim.models.Phrases(texts, scoring='npmi', threshold=0.7)
p = gensim.models.phrases.Phraser(ph)
new_ngrammed_texts = p[texts]

# %%
with open('ngrammed_texts.pkl', 'wb') as fw:
    pickle.dump(new_ngrammed_texts, fw)

# %%
with open('ngrammed_texts.pkl', 'rb') as f:
    new_ngrammed_texts = pickle.load(f)

# %%
new_lda_model, new_dictionary = get_lda_model(new_ngrammed_texts)
c, topics = get_coherence(new_lda_model, new_dictionary, new_ngrammed_texts, 20)
topics
# Out:
# Coherence:  0.47911614481876064
#    Topic # 00  Topic # 01 Topic # 02  Topic # 03    Topic # 04    Topic # 05  \
# 0   сообщение    значение       user  устройство    устройство          игра
# 1        игра        поле      admin   компьютер          сеть          цель
# 2    какой-то       канал       conn   процессор       сетевой          visa
# 3         мой      сигнал       test     ноутбук        сервер          тест
# 4      список        сеть      домен     windows        доступ  исследование
# 5      читать  устройство       role       рынок      интернет    устройство
# 6        сайт  переменный       тест      доллар        услуга          язык
# 7   приходить   усилитель       сайт     сегодня  безопасность          сеть
# 8       канал       адрес       файл         час        лекция     программа
# 9  заниматься     частота       зона   microsoft       очередь    неуловимый
#
#        Topic # 06   Topic # 07 Topic # 08 Topic # 09    Topic # 10  \
# 0          запрос         файл       игра       сайт       спутник
# 1          сервер         null      игрок     сервер        ракета
# 2      транзакция       сервис    игровой    хостинг        объект
# 3            сайт  уведомление     puppet     скидка         земля
# 4            база          can     играть     клиент        орбита
# 5         кластер       запрос   персонаж      домен   космический
# 6        хранение          not    история        the  пространство
# 7          сервис       сервер       salt      акция          язык
# 8  восстановление   управление     сервер        vps       планета
# 9            ключ          set     миньон    реклама           php
#
#       Topic # 11    Topic # 12  Topic # 13 Topic # 14 Topic # 15   Topic # 16  \
# 0           ключ         лампа      память     фигура     return       письмо
# 1           файл  исследование    значение       игра     string    галактика
# 2         pebble          игра        ядро   блокчейн       bool        адрес
# 3         сервер     популяция   процессор       поле     result  отправитель
# 4           сайт    испытуемый       поток      форма        int         файл
# 5        подпись           еще        цикл    биткойн       else    заголовок
# 6       открытый      какой-то  инструкция  двигатель      класс     значение
# 7            веб          мозг   программа        еще       byte        домен
# 8  злоумышленник    физический  компилятор     ошибка       void       сервер
# 9   безопасность   современный         int      метод      const      require
#
#    Topic # 17    Topic # 18 Topic # 19
# 0  javascript        доклад     запись
# 1         css   конференция       файл
# 2       точка     microsoft        int
# 3        язык        сервис    таблица
# 4    страница       vagrant    элемент
# 5         веб        devops        for
# 6  координата  тестирование       блок
# 7       ребро          тема       база
# 8         луч          база   операция
# 9        sass          data        log

# %% [markdown]
# Значение ```coherence``` немного уменьшилось, но зато теперь нет непонятных слов.

# %% [markdown]
# Посмотрим, как будет влиять число тем на ```coherence```:

# %%
for i in list(range(10, 100, 20)) + list(range(100, 400, 100)):
    model, dictionary = get_lda_model(new_ngrammed_texts, num_topics=i)
    print('n_topics: ', i)
    c, _ = get_coherence(model, dictionary, new_ngrammed_texts, 20)
# Out:
# n_topics:  10
# Coherence:  0.4010143289893584
# n_topics:  30
# Coherence:  0.47501931671571496
# n_topics:  50
# Coherence:  0.47559195912270347
# n_topics:  70
# Coherence:  0.480704778119817
# n_topics:  90
# Coherence:  0.47961027623006985
# n_topics:  100
# Coherence:  0.4644657910435386
# n_topics:  200
# Coherence:  0.4710407387468789
# n_topics:  300
# Coherence:  0.44355558574404313

# %% [markdown]
# Лучшее значение ```coherence``` получается при ```n_topics = 70```. Далее подберем параметр ```eta```:

# %%
for i in ['auto', 0.0001, 0.001, 0.01, 1]:
    model, dictionary = get_lda_model(new_ngrammed_texts, num_topics=70, eta=i)
    print('eta: ', i)
    c, _ = get_coherence(model, dictionary, new_ngrammed_texts, 20)
# Out:
# eta:  auto
# Coherence:  0.44883517373953136
# eta:  0.0001
# Coherence:  0.49950012071975536
# eta:  0.001
# Coherence:  0.4780575818101345
# eta:  0.01
# Coherence:  0.47699349066894964
# eta:  1
# Coherence:  0.43396530103294

# %% [markdown]
# В этом случае лучшее значение ```coherence``` получается при ```eta = 0.0001```. Далее подберем параметр ```passes```:

# %%
for i in range(5, 20, 5):
    model, dictionary = get_lda_model(new_ngrammed_texts, num_topics=70, eta=0.0001, passes=i)
    print('passes: ', i)
    c, _ = get_coherence(model, dictionary, new_ngrammed_texts, 20)
# Out:
# passes:  5
# Coherence:  0.48960886053795505
# passes:  10
# Coherence:  0.5468845248928476
# passes:  15
# Coherence:  0.5798874449347049

# %%
new_lda_model2, new_dictionary2, new_corpus2 = get_lda_model(new_ngrammed_texts, num_topics=70, eta=0.0001,
                                                                passes=15, return_corpus=True)
c, topics = get_coherence(new_lda_model2, new_dictionary2, new_ngrammed_texts, 20)
topics
# Out:
# Perplexity:  -90.86654043193215
# Coherence:  0.5428529646433754
#        Topic # 00 Topic # 01  Topic # 02     Topic # 03  Topic # 04  \
# 0  проектирование       глаз       товар     устройство      память
# 1            сайт   операция     магазин         камера         int
# 2            этап     нейрон      amazon       смартфон   процессор
# 3        прототип     сигнал  покупатель          экран        цикл
# 4       интерфейс  квантовый    доставка         модель   программа
# 5        страница      лазер      скидка        телефон  инструкция
# 6      требование   роговица       заказ        ноутбук  компилятор
# 7        дизайнер     зрение  фотография      компьютер    значение
# 8           макет      метод     покупка           цена         sum
# 9          спринт      линза     продажа  производитель         for
#
#       Topic # 05      Topic # 06          Topic # 07 Topic # 08  \
# 0           файл             the                язык   анимация
# 1           http      сертификат             регистр        var
# 2         сервер             pvs            контекст      токен
# 3      запускать      анализатор               scala        int
# 4         скрипт          ошибка            значение       ключ
# 5      настройка             ssl  предметный_область    элемент
# 6  устанавливать           linux        ограниченный        for
# 7      установка            root            сущность        eax
# 8           сайт        проверка              модель   function
# 9          https  предупреждение             агрегат     return
#
#            Topic # 09 Topic # 10      Topic # 11    Topic # 12  \
# 0                 php     docker    безопасность             d
# 1                база        amp            сеть        печать
# 2               linux  контейнер        интернет      материал
# 3           процессор      nginx           атака       принтер
# 4         архитектура     client          доступ  производство
# 5              сервер         lt          защита        деталь
# 6  производительность         if      устройство        модель
# 7           поддержка        run           связь       рабочий
# 8           программа     сервер  инфраструктура        станок
# 9                язык       char        оператор       изделие
#
#                Topic # 13   Topic # 14       Topic # 15  Topic # 16  \
# 0                    игра       доклад           сервер  библиотека
# 1                   игрок  конференция           сервис   ассемблер
# 2                 игровой         тема           запись   загрузчик
# 3                  играть  выступление          хостинг      лекция
# 4                   фильм        слайд           запрос      opencv
# 5                персонаж  презентация            объем  компилятор
# 6  виртуальный_реальность         язык       управление       cmake
# 7                 история     участник  резервный_копия     торрент
# 8                   экран          net              dns   программа
# 9                  движок         java           заявка        язык
#
#   Topic # 17 Topic # 18  Topic # 19
# 0      адрес   значение  транзакция
# 1      маска   алгоритм       tesla
# 2       сеть    элемент  блокировка
# 3    подсеть        int          pc
# 4        бит     список        субд
# 5       враг     массив      запрос
# 6       зона       блок     bitcoin
# 7       блок      точка  postgresql
# 8      игрок        for      ошибка
# 9    укрытие     ячейка  инструмент

# %%
topics[['Topic # 02', 'Topic # 13', 'Topic # 15']]
# Out:
#      Topic # 02   Topic # 13          Topic # 15
# 0       энергия      пациент                диск
# 1     вселенная       клетка              запись
# 2          свет         глаз              чтение
# 3        объект       ученый                 ssd
# 4        ученый     операция          накопитель
# 5      скорость         врач            участник
# 6     квантовый      лечение               набор
# 7  пространство      болезнь       configuration
# 8       частица     организм  оперативный_память
# 9         волна  заболевание              коммит

# %%
tfidf = gensim.models.TfidfModel(new_corpus2, id2word=new_dictionary2)
corpus = tfidf[new_corpus2]

# %%
tfidf_lda_model = get_lda_model(corpus, id2word=new_dictionary2,
                                                  num_topics=70, eta=0.0001,
                                                  passes=15, not_return_id2word=True)
c, topics = get_coherence(tfidf_lda_model, new_dictionary2, new_ngrammed_texts, 20)
topics
# Out:
# Perplexity:  -585.6361788529076
# Coherence:  0.4754481739540101
#           Topic # 00    Topic # 01     Topic # 02 Topic # 03  \
# 0                лед          void       electron      print
# 1            водород        public         печень       root
# 2         tensorflow         ionic      хромосома        cmd
# 3  благотворительный       кремний      пластинка       echo
# 4             кратер      рекурсия  срок_годность    include
# 5            seagate        sha256       iptables        usr
# 6             диплом        печкин         монета       file
# 7  электростимуляция       println     планшетный        set
# 8                хаб         admob    дикий_запад     define
# 9              тепло  quick_charge         пленка       хост
#
#            Topic # 04   Topic # 05      Topic # 06   Topic # 07  \
# 0               капча  регистратор            маяк     asterisk
# 1          activation     blackvue             ble         виза
# 2             тьюринг     подложка       оконечный   attributes
# 3                 oem  блокировщик            gulp        алмаз
# 4  болезнь_альцгеймер        train            лига  белорусский
# 5                дыра        opera         шорткат     фотонный
# 6             hotspot        оксид           фишер      foundry
# 7             counter     chromium       дед_мороз         грид
# 8          начальство      firefox            hero   изоморфный
# 9               clean      metrics  storage_spaces          crc
#
#            Topic # 08  Topic # 09 Topic # 10     Topic # 11   Topic # 12  \
# 0                nvme     vsphere     hyperx      измерение     вакансия
# 1          трансляция      random        pla         прибор       отклик
# 2                 vps     laravel        ddr       кандидат     эпидемия
# 3                 fjs        else    ротация         сердце    небоскреб
# 4  гиперконвергентный         gen    phpixie          сетка          руб
# 5             телеком   иннополис   kingston  собеседование     интеграл
# 6            selenium  middleware     фольга     гравитация  откликаться
# 7            highload     таймаут   филамент      помещение        макро
# 8                dusk        esxi      пират      гражданин        лазер
# 9                 eps  background        abs  синхронизация        пожар
#
#       Topic # 13     Topic # 14     Topic # 15        Topic # 16 Topic # 17  \
# 0           банк     sql_server         ураган  университет_итмо   nvarchar
# 1         услуга         openmp          ртуть            params        srv
# 2         платеж     потепление          кубит          итератор     протон
# 3        затрата           тень       банкомат                pg     elixir
# 4          azure            css        экзамен              null        mix
# 5           узел  многоугольник         пленка        postgresql     стакан
# 6    продвижение    гражданство    преподавать              moto    declare
# 7       telegram         models   мастер-класс               std       кожа
# 8  автоматизация    треугольник        тяньгун              siem        set
# 9       продавец        вебинар  видеоматериал             table    vector3
#
#     Topic # 18        Topic # 19
# 0    вселенная            таймер
# 1  космический         gpio_gpio
# 2      спутник              king
# 3      планета              gpio
# 4       орбита  кардиостимулятор
# 5    галактика               свч
# 6        земля             slave
# 7         марс            uint32
# 8       звезда              site
# 9         луна        amd_radeon

# %% [markdown]
# Также подберем параметры для ```tfidf_lda_model```.

# %%
for i in list(range(10, 100, 20)) + list(range(100, 400, 100)):
    print('n_topics: ', i)
    model = get_lda_model(corpus, id2word=new_dictionary2, num_topics=i, not_return_id2word=True)
    c, _ = get_coherence(model, new_dictionary2, new_ngrammed_texts, 20)
    print('---------')
# Out:
# n_topics:  10
# Perplexity:  -28.55893904207621
# Coherence:  0.36660456400876107
# ---------
# n_topics:  30
# Perplexity:  -68.34564091218033
# Coherence:  0.4620563386218245
# ---------
# n_topics:  50
# Perplexity:  -95.87415357053017
# Coherence:  0.4391479272885937
# ---------
# n_topics:  70
# Perplexity:  -117.98481797612159
# Coherence:  0.45152784989808287
# ---------
# n_topics:  90
# Perplexity:  -142.1472063097758
# Coherence:  0.42793024272375807
# ---------
# n_topics:  100
# Perplexity:  -155.85442506627237
# Coherence:  0.4531327273243862
# ---------
# n_topics:  200
# Perplexity:  -255.46357832229944
# Coherence:  0.4372549251552439
# ---------
# n_topics:  300
# Perplexity:  -345.6190266199971
# Coherence:  0.39989136757693394
# ---------

# %%
for i in ['auto', 0.0001, 0.001, 0.01, 1]:
    print('eta: ', i)
    model = get_lda_model(corpus, id2word=new_dictionary2, num_topics=100, eta=i,
                                     not_return_id2word=True)
    c, _ = get_coherence(model, new_dictionary2, new_ngrammed_texts, 20)
    print('---------')
# Out:
# eta:  auto
# Perplexity:  -156.55790518632816
# Coherence:  0.4527422541920901
# ---------
# eta:  0.0001
# Perplexity:  -2255.16931943488
# Coherence:  0.4382858419419209
# ---------
# eta:  0.001
# Perplexity:  -883.3172475456503
# Coherence:  0.45566458980377106
# ---------
# eta:  0.01
# Perplexity:  -250.00579302149288
# Coherence:  0.44667126432678456
# ---------
# eta:  1
# Perplexity:  -17.428973485674046
# Coherence:  0.3248440789308701
# ---------

# %%
for i in range(5, 20, 5):
    print('passes: ', i)
    model = get_lda_model(corpus, id2word=new_dictionary2, num_topics=100, eta=0.001,
                                     passes=i, not_return_id2word=True)
    c, _ = get_coherence(model, new_dictionary2, new_ngrammed_texts, 20)
    print('---------')
# Out:
# passes:  5
# Perplexity:  -873.6973041775655
# Coherence:  0.4284101308418729
# ---------
# passes:  10
# Perplexity:  -372.9551387676833
# Coherence:  0.46878352731528994
# ---------
# passes:  15
# Perplexity:  -255.1503151510508
# Coherence:  0.47697853435410736
# ---------

# %%
tfidf_lda_model = get_lda_model(corpus, id2word=new_dictionary2,
                                                  num_topics=70, eta=0.0001,
                                                  passes=10, not_return_id2word=True)
c, topics = get_coherence(tfidf_lda_model, new_dictionary2, new_ngrammed_texts, 20)
topics
# Out:
# Perplexity:  -1077.8257232136307
# Coherence:  0.45299134884316256
#   Topic # 00 Topic # 01          Topic # 02  Topic # 03  Topic # 04  \
# 0      react      fixed  болезнь_альцгеймер      сервер        dart
# 1         lt        ack               alias        язык        font
# 2       this        ops               канва        сайт         hpe
# 3  компонент  long_long              yellow        файл       style
# 4      props      книга         невесомость     элемент      appium
# 5        res        bim           подзапрос   сообщение  транзакция
# 6        jsx    jenkins          неуловимый   интерфейс     symfony
# 7     return         do             ansible  библиотека     display
# 8        val      ветка             moikrug    алгоритм    document
# 9      const   setstate                 нло       класс         mvp
#
#   Topic # 05                Topic # 06       Topic # 07 Topic # 08 Topic # 09  \
# 0        ssl                sharepoint            begin  tarantool       null
# 1    systemd                     форум            hyper        bmc    varchar
# 2     хостер                       clk      микросервис     python     select
# 3        tdd  объектно-ориентированный            yield          c      where
# 4      clion                       дгу            float       cuda   nvarchar
# 5      proxy                       int              лед        tox       from
# 6      nginx                 smalltalk  резервный_копия    водород      image
# 7        gen            assassin_creed              pla       riot     vector
# 8      ontap            криптовалютный              abs        лед        set
# 9    seagate             регулирование              spi      fixed    default
#
#    Topic # 10  Topic # 11    Topic # 12   Topic # 13 Topic # 14  Topic # 15  \
# 0  сертификат       выкуп          игра          цру      email        боль
# 1           o         nfc     сотрудник    приставка   рассылка       мышца
# 2  антибиотик         фас         игрок          hdr     письмо      trello
# 3      хирург     mongodb      облачный          nes  подписчик    препарат
# 4    sailfish    passport  безопасность        роман       conn  ibm_watson
# 5       yahoo     больной        бизнес          rom       role        врач
# 6     ctfzone   хромосома        услуга      эмпатия     фольга         шея
# 7    бактерия  пульсометр         земля      удалять        mix         ооо
# 8      backup  вымогатель         закон         пост     elixir         val
# 9         ctf   наказание        страна  бандеролька      пират     пациент
#
#   Topic # 16       Topic # 17   Topic # 18   Topic # 19
# 0     public  порекомендовать          num         мозг
# 1       void             марс         лига       нейрон
# 2        git          лайфхак     universe         кора
# 3      token     предпочитать       devops          art
# 4        org            книга      ротация         dusk
# 5        bot            scrum  беспилотник           gt
# 6        nov       литература        rails  подсознание
# 7     upload              час        oauth      summary
# 8        fmt             зонд   кибератака      minutes
# 9    redmine          блокнот    коворкинг          xff

# %%
topics[['Topic # 03', 'Topic # 09', 'Topic # 12']]
# Out:
#    Topic # 03 Topic # 09    Topic # 12
# 0      сервер       null          игра
# 1        язык    varchar     сотрудник
# 2        сайт     select         игрок
# 3        файл      where      облачный
# 4     элемент   nvarchar  безопасность
# 5   сообщение       from        бизнес
# 6   интерфейс      image        услуга
# 7  библиотека     vector         земля
# 8    алгоритм        set         закон
# 9       класс    default        страна

# %% [markdown]
# Изначально:
# * perplexity:  -90.86654043193215
# * coherence:  0.5428529646433754
#
# C tfidf:
# * perplexity:  -1077.8257232136307
# * coherence:  0.45299134884316256
#
# То есть, значительно улучшилось значение ```perplexity```, но ухудшилось значение ```coherence```. Если смотреть на топики, то там появилось больше английских слов и, как кажется, темы стали менее осмысленными.

# %% [markdown]
# ### Разложение матриц в sklearn

# %%
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(max_features=25000, ngram_range=(1, 2), min_df=5, max_df=0.3, lowercase=False, 
                             tokenizer=lambda x: x)
X = vectorizer.fit_transform(new_ngrammed_texts)

# %%
model = NMF(n_components=30)

# %%
model.fit(X)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#   n_components=30, random_state=None, shuffle=False, solver='cd',
#   tol=0.0001, verbose=0)

# %%
def get_nmf_topics(model, n_top_words):
    
    #id слов.
    feat_names = vectorizer.get_feature_names()
    
    word_dict = {};
    for i in range(model.components_.shape[0]):
        
        #топ n слов для темы.
        words_ids = model.components_[i].argsort()[:-n_top_words - 1:-1]
        words = [feat_names[key] for key in words_ids]
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = words;
    
    return pd.DataFrame(word_dict);

# %%
get_nmf_topics(model, 10)
# Out:
#   Topic # 01 Topic # 02    Topic # 03    Topic # 04 Topic # 05   Topic # 06  \
# 0     бизнес        the          игра          мозг         lt   устройство
# 1  сотрудник        and         игрок        ученый      lt lt       камера
# 2     клиент        for       игровой       пациент      class     смартфон
# 3    продукт        you        играть        клетка   lt class  аккумулятор
# 4     деньги       with      персонаж  исследование   class lt      дисплей
# 5      рынок       that         steam   заболевание       name          usb
# 6   заказчик        are         unity          врач  компонент    процессор
# 7        crm       your  игра который       болезнь    lt name        экран
# 8       опыт        not        движок           ген    элемент       корпус
# 9   менеджер     system          жанр      организм       type      ноутбук
#
#               Topic # 07   Topic # 08   Topic # 09         Topic # 10  \
# 0                   язык       public  космический              книга
# 1       программирование         void      спутник                час
# 2            программист  public void       орбита    порекомендовать
# 3  язык программирование          new       ракета   профессиональный
# 4                    php       string         марс       предпочитать
# 5                 лекция      private      аппарат               путь
# 6              программа       static        земля             музыка
# 7                   java          var      планета            слушать
# 8                перевод        класс         луна       пользоваться
# 9                 python       return        полет  внутренний проект
#
#      ...                   Topic # 21   Topic # 22     Topic # 23  Topic # 24  \
# 0    ...                        робот       объект        windows        сеть
# 1    ...                      ребенок  изображение      microsoft       связь
# 2    ...                робототехника     значение          linux    оператор
# 3    ...                       машина     алгоритм          azure      трафик
# 4    ...                       датчик       модель     обновление    интернет
# 5    ...                   автомобиль      элемент        браузер       канал
# 6    ...                     движение     текстура  visual_studio         dpi
# 7    ...                         дрон        метод            net  устройство
# 8    ...                     обучение        точка        драйвер     станция
# 9    ...      искусственный_интеллект        класс           ядро     абонент
#
#    Topic # 25      Topic # 26    Topic # 27       Topic # 28    Topic # 29  \
# 0         бот           товар             d             this          звук
# 1    telegram          скидка        печать         function        сигнал
# 2   сообщение            цена       принтер           return       наушник
# 3         чат         магазин      материал              var     усилитель
# 4         bot         покупка        станок        this this       частота
# 5         api      покупатель      печатать  public function        музыка
# 6       канал      распродажа  производство             self      звуковой
# 7  мессенджер  черный_пятница       изделие            const  акустический
# 8      телегр           рубль        деталь              new      акустика
# 9      сервис           акция        металл        компонент     искажение
#
#   Topic # 30
# 0        end
# 1      begin
# 2       null
# 3       from
# 4     select
# 5       then
# 6     запрос
# 7    varchar
# 8    таблица
# 9      where
#
# [10 rows x 30 columns]

# %%
def create_nmf(min_df=5, max_df=0.3, n_components=100):
    vectorizer = TfidfVectorizer(max_features=25000, ngram_range=(1, 2), min_df=min_df, max_df=max_df,
                                 lowercase=False, tokenizer=lambda x: x)
    X = vectorizer.fit_transform(new_ngrammed_texts)

    model = NMF(n_components=n_components)
    model.fit(X)

    print('reconstruction_err_: ', model.reconstruction_err_)
    
    return model, vectorizer

# %%
for i in range(20, 200, 50):
    print('n_components: ', i)
    model = create_nmf(min_df=5, max_df=0.3, n_components=i)
# Out:
# n_components:  20
# reconstruction_err_:  60.912338404172885
# n_components:  70
# reconstruction_err_:  58.46140927864674
# n_components:  120
# reconstruction_err_:  56.7739008448871
# n_components:  170
# reconstruction_err_:  55.38307361526634

# %%
# %%time
model1 = create_nmf(min_df=5, max_df=0.1, n_components=30)
# Out:
# reconstruction_err_:  61.07896438865475
# CPU times: user 1min 19s, sys: 9.61 s, total: 1min 29s
# Wall time: 1min 48s

# %%
# %%time
model2 = create_nmf(min_df=10, max_df=0.3, n_components=30)
# Out:
# reconstruction_err_:  60.149303186322555
# CPU times: user 2min 11s, sys: 7.76 s, total: 2min 18s
# Wall time: 2min 12s

# %%
# %%time
model, vectorizer = create_nmf(min_df=10, max_df=0.3, n_components=170)
# Out:
# reconstruction_err_:  55.114898403194545
# CPU times: user 13min 30s, sys: 3min, total: 16min 30s
# Wall time: 13min 22s

# %%
topics = get_nmf_topics(model, 10)
topics
# Out:
#         Topic # 01  Topic # 02    Topic # 03        Topic # 04 Topic # 05  \
# 0           бизнес       class          игра           энергия         lt
# 1              ита    lt class       игровой         солнечный      lt lt
# 2       управление    class lt        играть     электричество       name
# 3         директор       класс  игра который          источник    lt name
# 4  предприниматель          lt         steam  источник энергия       type
# 5     руководитель         yii        движок    электроэнергия    name lt
# 6              kpi  background         unity           реактор    lt type
# 7         развитие          gt      nintendo          мощность      value
# 8    трансформация        font      игра это             китай   value lt
# 9       финансовый     display     приставка            панель  компонент
#
#      Topic # 06  Topic # 07       Topic # 08   Topic # 09  Topic # 10  \
# 0          файл    какой-то           public         марс         css
# 1         папка      деньги             void  космический         веб
# 2        скрипт       жизнь      public void      аппарат  javascript
# 3        строка      думать          private         луна        html
# 4           имя      вообще         override        полет    фронтенд
# 5    директория        вещь  override public       миссия       стиль
# 6       каталог   приходить            float        земля         web
# 7          file  заниматься           static      планета        font
# 8  файл который       месяц    public static       космос  инструмент
# 9          путь       никто            class         зонд         svg
#
#       ...             Topic # 90        Topic # 91    Topic # 92   Topic # 93  \
# 0     ...                 python           продукт        станок        linux
# 1     ...             библиотека            дизайн           чпу         ядро
# 2     ...                asyncio          дизайнер  производство  дистрибутив
# 3     ...                 django         интерфейс      шпиндель      драйвер
# 4     ...             сообщество            design       изделие       ubuntu
# 5     ...                pycharm          прототип      алюминий         патч
# 6     ...                      c             экран       рабочий    поддержка
# 7     ...                   курс        инструмент        деталь       debian
# 8     ...             инструмент  пользовательский        металл   ядро linux
# 9     ...       программирование            иконка  изготовление      red_hat
#
#   Topic # 94  Topic # 95    Topic # 96      Topic # 97   Topic # 98  \
# 0        int       swift          сайт          сервис    двигатель
# 1    for int         let    посетитель          доступ      emdrive
# 2        for    анимация      интернет     микросервис         тяга
# 3      float       value       контент  сервис который    испытание
# 4    int int         ios        ресурс   работа сервис  космический
# 5     double       xcode    блокировка         сегмент      импульс
# 6       uint   objective       хостинг          онлайн          ток
# 7     return  компиляция  сайт который             мкс       космос
# 8  long_long        func         https        интернет       вакуум
# 9       char  компилятор  роскомнадзор       tarantool        стенд
#
#     Topic # 99
# 0      пациент
# 1         врач
# 2      лечение
# 3      болезнь
# 4        вирус
# 5  заболевание
# 6     препарат
# 7          вич
# 8        кровь
# 9       watson
#
# [10 rows x 170 columns]

# %%
topics[['Topic # 04', 'Topic # 06', 'Topic # 09', 'Topic # 92', 'Topic # 96', 'Topic # 99']]
# Out:
#          Topic # 04    Topic # 06   Topic # 09    Topic # 92    Topic # 96  \
# 0           энергия          файл         марс        станок          сайт
# 1         солнечный         папка  космический           чпу    посетитель
# 2     электричество        скрипт      аппарат  производство      интернет
# 3          источник        строка         луна      шпиндель       контент
# 4  источник энергия           имя        полет       изделие        ресурс
# 5    электроэнергия    директория       миссия      алюминий    блокировка
# 6           реактор       каталог        земля       рабочий       хостинг
# 7          мощность          file      планета        деталь  сайт который
# 8             китай  файл который       космос        металл         https
# 9            панель          путь         зонд  изготовление  роскомнадзор
#
#     Topic # 99
# 0      пациент
# 1         врач
# 2      лечение
# 3      болезнь
# 4        вирус
# 5  заболевание
# 6     препарат
# 7          вич
# 8        кровь
# 9       watson

# %% [markdown]
# И в LDA, и в NMF есть хорошие осмысленные темы, но в LDA их намного меньше, чем в NMF.
